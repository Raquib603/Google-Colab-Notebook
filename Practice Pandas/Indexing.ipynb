# %% [markdown]
# <a href="https://colab.research.google.com/github/Raquib603/Google-Colab-Notebook/blob/main/Indexing.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df = pd.read_csv('/content/world_population.csv', index_col= 'Country')
df.tail(5)
# Out:
#                    Rank CCA3   Capital Continent  2022 Population  \
# Country
# Wallis and Futuna   226  WLF  Mata-Utu   Oceania          11572.0
# Western Sahara      172  ESH  El Aaiún    Africa         575986.0
# Yemen                46  YEM     Sanaa      Asia       33696614.0
# Zambia               63  ZMB    Lusaka    Africa       20017675.0
# Zimbabwe             74  ZWE    Harare    Africa       16320537.0
#
#                    2020 Population  2015 Population  2010 Population  \
# Country
# Wallis and Futuna          11655.0          12182.0          13142.0
# Western Sahara            556048.0         491824.0         413296.0
# Yemen                   32284046.0       28516545.0       24743946.0
# Zambia                  18927715.0              NaN       13792086.0
# Zimbabwe                15669666.0       14154937.0       12839771.0
#
#                    2000 Population  1990 Population  1980 Population  \
# Country
# ...

# %%
#make country as index
df.reset_index(inplace=True)
df
# Out:
#                Country  index  Rank CCA3           Capital Continent  \
# 0          Afghanistan      0    36  AFG             Kabul      Asia
# 1              Albania      1   138  ALB            Tirana    Europe
# 2              Algeria      2    34  DZA           Algiers    Africa
# 3       American Samoa      3   213  ASM         Pago Pago   Oceania
# 4              Andorra      4   203  AND  Andorra la Vella    Europe
# ..                 ...    ...   ...  ...               ...       ...
# 229  Wallis and Futuna    229   226  WLF          Mata-Utu   Oceania
# 230     Western Sahara    230   172  ESH          El Aaiún    Africa
# 231              Yemen    231    46  YEM             Sanaa      Asia
# 232             Zambia    232    63  ZMB            Lusaka    Africa
# 233           Zimbabwe    233    74  ZWE            Harare    Africa
#
#      2022 Population  2020 Population  2015 Population  2010 Population  \
# ...

# %%
df.set_index('Country', inplace = True)
df
# Out:
#                    index  Rank CCA3           Capital Continent  \
# Country
# Afghanistan            0    36  AFG             Kabul      Asia
# Albania                1   138  ALB            Tirana    Europe
# Algeria                2    34  DZA           Algiers    Africa
# American Samoa         3   213  ASM         Pago Pago   Oceania
# Andorra                4   203  AND  Andorra la Vella    Europe
# ...                  ...   ...  ...               ...       ...
# Wallis and Futuna    229   226  WLF          Mata-Utu   Oceania
# Western Sahara       230   172  ESH          El Aaiún    Africa
# Yemen                231    46  YEM             Sanaa      Asia
# Zambia               232    63  ZMB            Lusaka    Africa
# Zimbabwe             233    74  ZWE            Harare    Africa
#
#                    2022 Population  2020 Population  2015 Population  \
# Country
# Afghanistan             41128771.0       38972230.0       33753499.0
# ...

# %% [markdown]
# # Search through index

# %%
#by value
df.loc['Albania']

# %%
#by direct integer input
df.iloc[1]

# %%
df.reset_index(drop=True, inplace=True) # Add drop=True to avoid creating the 'level_0' column
df.set_index('index', inplace=True)
df
# Out:
#                  Country  Rank CCA3           Capital Continent  \
# index
# 0            Afghanistan    36  AFG             Kabul      Asia
# 1                Albania   138  ALB            Tirana    Europe
# 2                Algeria    34  DZA           Algiers    Africa
# 3         American Samoa   213  ASM         Pago Pago   Oceania
# 4                Andorra   203  AND  Andorra la Vella    Europe
# ...                  ...   ...  ...               ...       ...
# 229    Wallis and Futuna   226  WLF          Mata-Utu   Oceania
# 230       Western Sahara   172  ESH          El Aaiún    Africa
# 231                Yemen    46  YEM             Sanaa      Asia
# 232               Zambia    63  ZMB            Lusaka    Africa
# 233             Zimbabwe    74  ZWE            Harare    Africa
#
#        2022 Population  2020 Population  2015 Population  2010 Population  \
# index
# 0           41128771.0       38972230.0       33753499.0       28189672.0
# ...

# %%
df.sort_index(ascending=False, inplace= True)
df
# Out:
#                  Country  Rank CCA3           Capital Continent  \
# index
# 233             Zimbabwe    74  ZWE            Harare    Africa
# 232               Zambia    63  ZMB            Lusaka    Africa
# 231                Yemen    46  YEM             Sanaa      Asia
# 230       Western Sahara   172  ESH          El Aaiún    Africa
# 229    Wallis and Futuna   226  WLF          Mata-Utu   Oceania
# ...                  ...   ...  ...               ...       ...
# 4                Andorra   203  AND  Andorra la Vella    Europe
# 3         American Samoa   213  ASM         Pago Pago   Oceania
# 2                Algeria    34  DZA           Algiers    Africa
# 1                Albania   138  ALB            Tirana    Europe
# 0            Afghanistan    36  AFG             Kabul      Asia
#
#        2022 Population  2020 Population  2015 Population  2010 Population  \
# index
# 233         16320537.0       15669666.0       14154937.0       12839771.0
# ...
