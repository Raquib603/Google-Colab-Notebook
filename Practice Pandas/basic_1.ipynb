# %% [markdown]
# <a href="https://colab.research.google.com/github/Raquib603/Google-Colab-Notebook/blob/main/basic_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df = pd.read_csv('/content/bike_share_yr_1.csv')
#dataframe is simply rows and columns in the data
#same for the excel files
df.head(10)

# %%
#delete the headers
#set new names to headers : header = none, names = ['a', 'b', 'c']
df = pd.read_csv('/content/bike_share_yr_1.csv', header = None)
df.head()

# %%
df.shape
df.info()

# %%
pd.set_option('display.max.rows',200)
pd.set_option('display.max.columns',20)

# %%
#to show the last values
df.tail(10)
# Out:
#            dteday  season  yr  mnth  hr  holiday  weekday  workingday  \
# 17458  31/12/2022       1   1    12  14        0        1           1
# 17459  31/12/2022       1   1    12  15        0        1           1
# 17460  31/12/2022       1   1    12  16        0        1           1
# 17461  31/12/2022       1   1    12  17        0        1           1
# 17462  31/12/2022       1   1    12  18        0        1           1
# 17463  31/12/2022       1   1    12  19        0        1           1
# 17464  31/12/2022       1   1    12  20        0        1           1
# 17465  31/12/2022       1   1    12  21        0        1           1
# 17466  31/12/2022       1   1    12  22        0        1           1
# 17467  31/12/2022       1   1    12  23        0        1           1
#
#        weathersit  temp   atemp   hum  windspeed  rider_type  riders
# 17458           2  0.28  0.2727  0.45     0.2239  registered     185
# ...

# %%
#to see the specific row`
df.loc[17466]

# %%
#to see the columns
df.columns
# Out:
# Index(['dteday', 'season', 'yr', 'mnth', 'hr', 'holiday', 'weekday',
#        'workingday', 'weathersit', 'temp', 'atemp', 'hum', 'windspeed',
#        'rider_type', 'riders'],
#       dtype='object')
