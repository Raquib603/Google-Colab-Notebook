# %% [markdown]
# <a href="https://colab.research.google.com/github/Raquib603/Google-Colab-Notebook/blob/main/Drop_column.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df = pd.read_csv('/content/world_population.csv')
df.tail(5)

# %%
df.set_index('Rank', inplace = True)
df

# %%
df.sort_index(ascending = True, inplace = True)
df.head(6)

# %%
#0 means that we are selecting rows, 1 means that we are selecting columns
df.drop('Capital', axis= 1, inplace = True)
df
# Out:
#      CCA3           Country      Continent  2022 Population  2020 Population  \
# Rank
# 1     CHN             China           Asia     1.425887e+09     1.424930e+09
# 2     IND             India           Asia     1.417173e+09     1.396387e+09
# 3     USA     United States  North America     3.382899e+08     3.359420e+08
# 4     IDN         Indonesia           Asia     2.755013e+08     2.718580e+08
# 5     PAK          Pakistan           Asia     2.358249e+08     2.271967e+08
# ...   ...               ...            ...              ...              ...
# 230   MSR        Montserrat  North America     4.390000e+03     4.500000e+03
# 231   FLK  Falkland Islands  South America     3.780000e+03     3.747000e+03
# 232   NIU              Niue        Oceania     1.934000e+03     1.942000e+03
# 233   TKL           Tokelau        Oceania     1.871000e+03     1.827000e+03
# 234   VAT      Vatican City         Europe     5.100000e+02     5.200000e+02
#
# ...
